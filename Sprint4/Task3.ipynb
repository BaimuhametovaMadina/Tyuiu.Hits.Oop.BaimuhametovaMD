// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [ваш текст]
//
// #### Дополнительное задание
// Добавьте к сущестующим классам (базовыму и производным 3-4 атрибута и метода) создайте явную реализации интерфейса и управление зависимостями

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;
using System.Collections.Generic;

public interface IEmployee
{
    void GetInfo();
    void Work();
    void TakeVacation();
}

public abstract class Employee : IEmployee
{
    public string Name { get; set; }
    public int Age { get; set; }
    public int Salary { get; set; }

    public Employee(string name, int age, int salary)
    {
        Name = name;
        Age = age;
        Salary = salary;
    }

    // Явная реализация интерфейса
    void IEmployee.GetInfo()
    {
        Console.WriteLine($"Базовая информация: {Name}, {Age} лет, зарплата {Salary}");
    }

    void IEmployee.Work()
    {
        Console.WriteLine($"{Name} выполняет базовую работу.");
    }

    void IEmployee.TakeVacation()
    {
        Console.WriteLine($"{Name} берет стандартный отпуск.");
    }

    // Публичные абстрактные методы для переопределения
    public abstract void GetInfo();
    public abstract void Work();
    public abstract void TakeVacation();
}

public class Manager : Employee, IEmployee
{
    public int SubordinatesCount { get; private set; }

    public Manager(string name, int age, int salary, int subCount) : base(name, age, salary)
    {
        SubordinatesCount = subCount;
    }

    public override void GetInfo()
    {
        Console.WriteLine($"Имя: {Name}, Возраст: {Age}, Зарплата: {Salary}, Подчиненных: {SubordinatesCount}");
    }

    public override void Work()
    {
        Console.WriteLine($"{Name} управляет командой из {SubordinatesCount} человек.");
    }

    public override void TakeVacation()
    {
        Console.WriteLine($"{Name} уходит в отпуск.");
    }

    public void TakeVacation(int days)
    {
        Console.WriteLine($"{Name} уходит в отпуск на {days} дней.");
    }
}

public class Developer : Employee, IEmployee
{
    public string Specialization { get; set; }

    public Developer(string name, int age, int salary, string specialization)
        : base(name, age, salary)
    {
        Specialization = specialization;
    }

    public override void GetInfo()
    {
        Console.WriteLine($"Имя: {Name}, Возраст: {Age}, Зарплата: {Salary}, Специализация: {Specialization}");
    }

    public override void Work()
    {
        Console.WriteLine($"{Name} пишет код по специализации {Specialization}.");
    }

    public override void TakeVacation()
    {
        Console.WriteLine($"{Name} уходит в отпуск.");
    }

    public void TakeVacation(Developer otherDev)
    {
        Console.WriteLine($"{Name} спрашивает специализацию у {otherDev.Name}: {otherDev.Specialization}");
        Console.WriteLine($"{Name} идёт в отпуск.");
    }
}

public class SeniorDeveloper : Developer, IEmployee
{
    public int ExperienceYears { get; set; }

    public SeniorDeveloper(string name, int age, int salary, string specialization, int experienceYears)
        : base(name, age, salary, specialization)
    {
        ExperienceYears = experienceYears;
    }

    public override void GetInfo()
    {
        base.GetInfo();
        Console.WriteLine($"Опыт работы: {ExperienceYears} лет");
    }

    public override void Work()
    {
        Console.WriteLine($"{Name} разрабатывает сложные проекты с опытом {ExperienceYears} лет.");
    }

    public new void TakeVacation()
    {
        Console.WriteLine($"{Name} (Senior Developer) уходит в отпуск с дополнительными бонусами.");
    }
}

public interface ILeader
{
    void LeadTeam();
}

public interface IDesigner
{
    void Design();
}

public class LeadDesigner : Employee, ILeader, IDesigner
{
    public string DesignStyle { get; set; }
    public int TeamSize { get; set; }

    public LeadDesigner(string name, int age, int salary, string designStyle, int teamSize)
        : base(name, age, salary)
    {
        DesignStyle = designStyle;
        TeamSize = teamSize;
    }

    public override void GetInfo()
    {
        Console.WriteLine($"Имя: {Name}, Возраст: {Age}, Зарплата: {Salary}, Стиль дизайна: {DesignStyle}, Размер команды: {TeamSize}");
    }

    public override void Work()
    {
        LeadTeam();
        Design();
    }

    public override void TakeVacation()
    {
        Console.WriteLine($"{Name} уходит в отпуск.");
    }

    public void LeadTeam()
    {
        Console.WriteLine($"{Name} руководит командой из {TeamSize} человек.");
    }

    public void Design()
    {
        Console.WriteLine($"{Name} создает дизайн в стиле {DesignStyle}.");
    }
}

public class EmployeeService
{
    private readonly IEmployee _employee;

    public EmployeeService(IEmployee employee)
    {
        _employee = employee;
    }

    public void ManageEmployee()
    {
        _employee.GetInfo();
        _employee.Work();
        _employee.TakeVacation();
        Console.WriteLine();
    }
}

public class EmployeeManager<T> where T : Employee, IEmployee
{
    private List<T> employees = new List<T>();

    public void AddEmployee(T employee)
    {
        employees.Add(employee);
    }

    public void ShowAllInfo()
    {
        foreach (var emp in employees)
        {
            ((IEmployee)emp).GetInfo();
            Console.WriteLine();
        }
    }

    public void MakeAllWork()
    {
        foreach (var emp in employees)
        {
            ((IEmployee)emp).Work();
            Console.WriteLine();
        }
    }
}


Manager mgr = new Manager("Анна", 40, 70000, 10);
mgr.GetInfo();
mgr.Work();
mgr.TakeVacation();
mgr.TakeVacation(14);

SeniorDeveloper seniorDev = new SeniorDeveloper("Иван", 30, 80000, "Backend", 8);
seniorDev.GetInfo();
seniorDev.Work();
seniorDev.TakeVacation();

LeadDesigner leadDesigner = new LeadDesigner("Ольга", 35, 90000, "Минимализм", 5);
leadDesigner.GetInfo();
leadDesigner.Work();
leadDesigner.TakeVacation();
Developer dev1 = new Developer("Дмитрий", 28, 60000, "Frontend");
Developer dev2 = new Developer("Елена", 26, 62000, "Fullstack");
dev1.TakeVacation(dev2);

List<Employee> staff = new List<Employee> { mgr, seniorDev, leadDesigner, dev1, dev2 };

foreach (var emp in staff)
{
    emp.GetInfo();
    emp.Work();
    emp.TakeVacation();
    Console.WriteLine();
}
EmployeeManager<Employee> employeeManager = new EmployeeManager<Employee>();
employeeManager.AddEmployee(mgr);
employeeManager.AddEmployee(seniorDev);
employeeManager.AddEmployee(dev1);
employeeManager.AddEmployee(leadDesigner);

Console.WriteLine("Generic класс - вывод информации о сотрудниках:");
employeeManager.ShowAllInfo();

Console.WriteLine("Generic класс - вызов работы всех сотрудников:");
employeeManager.MakeAllWork();

Console.WriteLine("=== Dependency Injection ===");
IEmployee managerAsEmployee = mgr;
EmployeeService managerService = new EmployeeService(managerAsEmployee);
managerService.ManageEmployee();

IEmployee seniorDevAsEmployee = seniorDev;
EmployeeService seniorService = new EmployeeService(seniorDevAsEmployee);
seniorService.ManageEmployee();
// Out:
// Имя: Анна, Возраст: 40, Зарплата: 70000, Подчиненных: 10
// Анна управляет командой из 10 человек.
// Анна уходит в отпуск.
// Анна уходит в отпуск на 14 дней.
// Имя: Иван, Возраст: 30, Зарплата: 80000, Специализация: Backend
// Опыт работы: 8 лет
// Иван разрабатывает сложные проекты с опытом 8 лет.
// Иван (Senior Developer) уходит в отпуск с дополнительными бонусами.
// Имя: Ольга, Возраст: 35, Зарплата: 90000, Стиль дизайна: Минимализм, Размер команды: 5
// Ольга руководит командой из 5 человек.
// Ольга создает дизайн в стиле Минимализм.
// Ольга уходит в отпуск.
// Дмитрий спрашивает специализацию у Елена: Fullstack
// Дмитрий идёт в отпуск.
// Имя: Анна, Возраст: 40, Зарплата: 70000, Подчиненных: 10
// Анна управляет командой из 10 человек.
// Анна уходит в отпуск.
//
// Имя: Иван, Возраст: 30, Зарплата: 80000, Специализация: Backend
// Опыт работы: 8 лет
// Иван разрабатывает сложные проекты с опытом 8 лет.
// Иван уходит в отпуск.
//
// Имя: Ольга, Возраст: 35, Зарплата: 90000, Стиль дизайна: Минимализм, Размер команды: 5
// Ольга руководит командой из 5 человек.
// Ольга создает дизайн в стиле Минимализм.
// Ольга уходит в отпуск.
//
// Имя: Дмитрий, Возраст: 28, Зарплата: 60000, Специализация: Frontend
// Дмитрий пишет код по специализации Frontend.
// Дмитрий уходит в отпуск.
//
// Имя: Елена, Возраст: 26, Зарплата: 62000, Специализация: Fullstack
// Елена пишет код по специализации Fullstack.
// Елена уходит в отпуск.
//
// Generic класс - вывод информации о сотрудниках:
// Имя: Анна, Возраст: 40, Зарплата: 70000, Подчиненных: 10
//
// Имя: Иван, Возраст: 30, Зарплата: 80000, Специализация: Backend
// Опыт работы: 8 лет
//
// Имя: Дмитрий, Возраст: 28, Зарплата: 60000, Специализация: Frontend
//
// Базовая информация: Ольга, 35 лет, зарплата 90000
//
// Generic класс - вызов работы всех сотрудников:
// Анна управляет командой из 10 человек.
//
// Иван разрабатывает сложные проекты с опытом 8 лет.
//
// Дмитрий пишет код по специализации Frontend.
//
// Ольга выполняет базовую работу.
//
// === Dependency Injection ===
// Имя: Анна, Возраст: 40, Зарплата: 70000, Подчиненных: 10
// Анна управляет командой из 10 человек.
// Анна уходит в отпуск.
//
// Имя: Иван, Возраст: 30, Зарплата: 80000, Специализация: Backend
// Опыт работы: 8 лет
// Иван разрабатывает сложные проекты с опытом 8 лет.
// Иван (Senior Developer) уходит в отпуск с дополнительными бонусами.
